# %%
import litellm

from typing_extensions import TypedDict

from pydantic import TypeAdapter, ValidationError
from pydantic import BaseModel, Field

# %%
# https://stackoverflow.com/a/8369345

story = "C:/Users/leona/ai-engineering-fordham/the-vineyard.txt"

with open(story, "r", encoding = "utf-8") as s:
    string = s.read()

print(string)
# Out:
# The Plaintext File of The Vineyard
#
# Title: The Vineyard
#
# Author: LC
#
# Release date: April 1, 2026
# Most recently updated: March 31, 2026
#
# Language: English
#
# *** START OF THE PLAINTEXT FILE THE VINEYARD ***
#
# THE VINEYARD:
#
# BEING AN EXTRACT FROM THE  IMAGINATION OF A SCHOLAR.
#
# by LC
#
# Chapter 1 - Making Plans
#
# Jack and Jill were excited to go to the dog park again, hoping to see their newfound four-legged friend Spot.
# As they crossed the street toward the entrance, they broke from a stroll into a jog,
# having seen Spot's humans Dick and Jane in those signature neon windbreakers.
# Spot's gaze met theirs, and the little terrier mix bounded over,
# much to Jane's panic (she was always the cautious one in the couple).
# To everyone's relief, Spot pulled short of the fenceline, yipping affectionately.
#
# Jill had come prepared with treats, and as she squatted down to give head pats,
# the scent of salmon drove Spot into a leaping frenzy,
# his slightly muddy paws leaving streaks on the white jeans that Jack had bought for her birthday.
#
# "Nothing a bit of detergent won't fix," Jack assured himself. It had been a difficult move to an unfamiliar city,
# and the social contact was worth the laundry.
#
# After Jane managed to wrangle Spot back onto leash,
# the foursome found their way to a picnic table and made small talk under the afternoon sun;
# for his part, Spot slobbered busily over his chew toy.
# From behind his aviators, Dick floated the idea of visiting the vineyard in the next county over when June rolled around,
# and though Jack was, if anything, a beer guy,
# he nodded and crinkled his eyes just enough to look enthusiastic about the idea.
# He glanced at Jill, whose seemingly-agreeing smile– after two years together, he could tell– belied a similar reluctance.
#
# But they didn't know anyone else in town, and they didn't have anything lined up for the summer:
# Siri, add Thousand Oaks Tour to the Google Calendar.
#
# *** END OF THE PLAINTEXT FILE THE VINEYARD ***

# %%
class Extract(BaseModel):
    characters: list[str] = Field(
        "dramatis personae"
        )
    interactions: list[str] = Field(
        "plot points"
        )

# %%
response = litellm.completion(
    model = "gpt-5-nano",
    messages = [
        {
            "role": "user",
            "content": f"Identify the narrative characters in this story: {string}, and explain the interactions between them."
            }
            ],
        response_format = Extract
        )

# %%
print(response.choices[0].message.content)
# Out:
# {"characters":["Jack","Jill","Spot","Dick","Jane"],"interactions":["Jack and Jill are a couple whose dynamic shows Jack's enthusiasm for social plans and Jill's measured optimism, peeking through as Jill's smile belies reluctance about summer plans.","Dick and Jane are Spot's humans; Dick initiates the idea of visiting the vineyard while Jane's cautious nature keeps the suggestion grounded.","Spot acts as the social catalyst, greeting the group with affection and energetic movement, influencing their interaction and drawing them into shared activity.","The dog park and picnic table scene provide the social stage where the couples talk, observe Spot's behavior, and form early plans together.","A common goal emerges: despite uncertainty about summer social life in a new town, the group incrementally agrees to visit the vineyard in June, signaling growing social ties.","Technology enters the planning process when the line 'Siri, add Thousand Oaks Tour to the Google Calendar' shows the characters relying on digital tools to coordinate future plans."]}

# %%
response2 = litellm.completion(
    model = "gpt-5-nano",
    messages = [
        {
            "role": "user",
            "content": f"From {response}, create the syntax for a Mermaid.js sequence diagram."
            }
            ]
)

# %%
print(response2.choices[0].message.content)
# Out:
# Here is a Mermaid.js sequence diagram syntax that captures the interactions described.
#
# ```mermaid
# sequenceDiagram
#     participant Jack
#     participant Jill
#     participant Spot
#     participant Dick
#     participant Jane
#     participant Vineyard
#     participant Siri
#     participant Calendar
#
#     Jack -> Jill: Jack's enthusiasm for social plans
#     Jill -> Jack: Jill's measured optimism; reluctance about summer plans
#     Spot -> Jack: Spot greets with affection and energetic movement
#     Spot -> Jill: Spot greets with affection and energetic movement
#     Dick -> Jane: Dick initiates idea of visiting the vineyard
#     Jane -> Dick: Jane is cautious; keeps suggestion grounded
#     Note over Jack, Jill, Spot, Dick, Jane: Spot acts as social catalyst; draws group into shared activity
#     Jack -> Vineyard: propose visiting the vineyard in June
#     Jill -> Vineyard: discuss potential June visit
#     Dick -> Vineyard: advocates vineyard trip
#     Jane -> Vineyard: notes concerns about the plan
#     Note over Jack, Jill, Dick, Jane, Spot: Dog park and picnic table scene provides the social stage
#     Siri -> Calendar: "Add Thousand Oaks Tour" to Google Calendar
#     Calendar -> Siri: Confirmation
# ```
